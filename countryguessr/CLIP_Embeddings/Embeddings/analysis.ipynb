# %%
import pandas as pd

#geo_weak = pd.read_csv('Training/geo_weakly_balanced.csv')
geo_strong = pd.read_csv('Training/geo_strongly_balanced.csv')
#mixed_geo_weak = pd.read_csv('Training/mixed_weakly_balanced.csv')
#mixed_geo_strong = pd.read_csv('Training/mixed_strongly_balanced.csv')


#country_list = pd.read_csv('./../data_finding/country_list_region.csv')

#geo_weak_with_regions = geo_weak.merge(country_list, left_on='label', right_on='Country', how='left')
#geo_strong_with_regions = geo_strong.merge(country_list, left_on='label', right_on='Country', how='left')
#mixed_geo_weak_with_regions = mixed_geo_weak.merge(country_list, left_on='label', right_on='Country', how='left')
#mixed_geo_strong_with_regions = mixed_geo_strong.merge(country_list, left_on='label', right_on='Country', how='left')

# %%
print(geo_strong.value_counts('label')[geo_strong.value_counts('label')<50])
print(geo_strong.value_counts('label')["Finland"])
print(geo_strong.value_counts('label')["Sweden"])
print(geo_strong.value_counts('label')["Denmark"])
# Out:
# label
# Israel        False
# Finland       False
# Germany       False
# Greece        False
# Indonesia     False
#               ...
# Madagascar     True
# Macau          True
# Andorra        True
# China          True
# Jersey         True
# Length: 93, dtype: bool
# 200
# 200
# 168

# %%
geo_weak_with_regions.value_counts('Intermediate Region Name')
labels_less_than_100 = geo_strong_with_regions['label'].value_counts().plot.bar()

# %%
print((geo_weak.groupby('label').count()))
geo_distr = pd.read_csv('/home/lbrenig/Documents/Uni/GPML/good_practices_ml/data_exploration/GeoGuesser/image_distribution.csv')
geo_distr['label'].value_counts()
# Out:
#                       width  height  format  path  Embedding  model_input
# label
# Albania                  35      35      35    35         35           35
# Andorra                  11      11      11    11         11           11
# Argentina               586     586     586   586        586          586
# Australia              1448    1448    1448  1448       1448         1448
# Austria                 295     295     295   295        295          295
# ...                     ...     ...     ...   ...        ...          ...
# United Arab Emirates     59      59      59    59         59           59
# United Kingdom         1700    1700    1700  1700       1700         1700
# United States          1700    1700    1700  1700       1700         1700
# Uruguay                  48      48      48    48         48           48
# Vietnam                  13      13      13    13         13           13
#
# [95 rows x 6 columns]
# label
# Venezuela        1
# United States    1
# Japan            1
# France           1
# Iraq             1
#                 ..
# Canada           1
# South Africa     1
# Spain            1
# Finland          1
# Thailand         1
# Name: count, Length: 124, dtype: int64
